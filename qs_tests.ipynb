# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('BX')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# 0.46977511670075595

# %%
index = {"SPY": 1.3, "AGG": -.3}
portfolio = qs.utils.make_index(index, period='3y')
portfolio.index = portfolio.index.tz_localize(None)
portfolio.plot_earnings(start_balance= 10000)
# Out:
# C:\Users\Manny\anaconda3\lib\site-packages\quantstats\utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)

# %%
port_dict = {'AAPL': 0.3, 'AMZN': 0.3, 'NVDA': 0.41469118072} 

benchmark_dict = {'SPY': 1.0}

# %%
port_index = qs.utils.make_index(port_dict)
benchmark_index = qs.utils.make_index(benchmark_dict)

qs.reports.basic(port_index, benchmark_index)
# Out:
# C:\Users\Manny\anaconda3\lib\site-packages\quantstats\utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)
# C:\Users\Manny\anaconda3\lib\site-packages\quantstats\utils.py:394: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)
# <h4>Performance Metrics</h4>
#                     Strategy     Benchmark
# ------------------  -----------  -----------
# Start Period        1999-01-25   1999-01-25
# End Period          2023-03-24   2023-03-24
# Risk-Free Rate      0.0%         0.0%
# Time in Market      99.0%        99.0%
#
# Cumulative Return   526,102.20%  394.88%
# CAGR﹪              42.54%       6.84%
#
# Sharpe              0.88         0.43
# Prob. Sharpe Ratio  100.0%       98.35%
# Sortino             1.31         0.61
# Sortino/√2          0.93         0.43
# Omega               1.18         1.18
#
# Max Drawdown        -99.84%      -55.19%
# Longest DD Days     2779         2404
#
# Gain/Pain Ratio     0.18         0.09
# Gain/Pain (1M)      1.01         0.52
#
# Payoff Ratio        0.94         0.88
# Profit Factor       1.18         1.09
# Common Sense Ratio  1.22         0.99
# CPC Index           0.6          0.51
# Tail Ratio          1.04         0.91
# Outlier Win Ratio   2.5          15.7
# Outlier Loss Ratio  2.28         13.1
#
# MTD                 34.17%       0.25%
# 3M                  134.1%       3.75%
# 6M                  64.42%       8.46%
# YTD                 152.69%      3.88%
# 1Y                  -63.08%      -9.32%
# 3Y (ann.)           35.97%       14.51%
# 5Y (ann.)           25.85%       10.26%
# 10Y (ann.)          90.86%       11.83%
# All-time (ann.)     42.54%       6.84%
#
# Avg. Drawdown       -13.19%      -2.08%
# Avg. Drawdown Days  64           32
# Recovery Factor     5269.66      7.16
# Ulcer Index         0.68         0.17
# Serenity Index      483.26       0.91
# <h4>Strategy Visualization</h4>
